# %%
import panel as pn
pn.extension('plotly')
import pandas as pd
import hvplot.pandas
import matplotlib.pyplot as plt
import numpy as np
import os
from pathlib import Path
from dotenv import load_dotenv
import warnings
warnings.filterwarnings('ignore')
import plotly.express as px

# %%
file_path_imdb = Path("Data/movie_metadata.csv")
imdb_data = pd.read_csv(file_path_imdb)
imdb_data.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
imdb_data_copy =imdb_data.drop_duplicates()

# %%
#imdb_data_copy

# %%
starwars_film = {'director_name': 'J.J. Abrams' ,
             'duration':136 , 'actor_2_name':'John Boyega' , 'actor_1_name': 'Daisy Ridley' ,
             'actor_3_name':'Oscar Isaac', 'gross':2066000000 ,'movie_title': 'Star Wars Ep. VII: The Force Awakens',
             'facenumber_in_poster':4.0 , 'movie_imdb_link':'https://www.imdb.com/title/tt2488496/' ,
             'content_rating':'PG-13' ,'title_year':2015, 
             'budget':306000000, 'imdb_score': 7.8 , 'country': 'USA'}
dory_film = {'director_name': 'Andrew Stanton' ,
             'duration':97 , 'actor_2_name':'Albert Brooks' , 'actor_1_name': 'Ellen DeGeneres' ,
             'actor_3_name':"Ed O'Neill", 'gross':1029000000 ,'movie_title': 'Finding Dory',
             'facenumber_in_poster':0.0 , 'movie_imdb_link':'https://www.imdb.com/title/tt2277860/?ref_=fn_al_tt_1' ,
             'content_rating':'PG' ,'title_year':2016, 
             'budget':94000000, 'imdb_score': 7.3 , 'country': 'USA'}

second_starwars_film =  {'director_name': 'Rian Johnson' ,
             'duration':152 , 'actor_2_name':'John Boyega' ,
                        'actor_1_name': 'Daisy Ridley' ,
             'actor_3_name':"Mark Hamill", 'gross':1333000000 ,'movie_title': 'Star Wars Ep. VIII: The Last Jedi ',
             'facenumber_in_poster':7.0 , 'movie_imdb_link':'https://www.imdb.com/title/tt2527336/' ,
             'content_rating':'PG-13' ,'title_year':2017, 
             'budget':370000000, 'imdb_score': 6.9 , 'country': 'USA'}
black_panther = {'director_name': 'Ryan Coogler' ,
             'duration':135 , 'actor_2_name':'Michael B. Jordan' ,
                        'actor_1_name': 'Chadwick Boseman' ,
             'actor_3_name':"Lupita Nyong'o", 'gross':1344000000  ,'movie_title': 'Black Panther',
             'facenumber_in_poster':10.0 , 'movie_imdb_link':'https://www.imdb.com/title/tt1825683/' ,
             'content_rating':'PG-13' ,'title_year':2018, 
             'budget':200000000, 'imdb_score': 7.3 , 'country': 'USA'}

end_game = {'director_name': 'Russo Brothers' ,
             'duration':182 , 'actor_2_name':'Chris Evans' ,
                        'actor_1_name': 'Robert Downey Jr.' ,
             'actor_3_name':"Mark Ruffalo", 'gross':2503000000 ,'movie_title': 'Avengers: Endgame',
             'facenumber_in_poster':11.0 , 'movie_imdb_link':'https://www.imdb.com/title/tt4154796/' ,
             'content_rating':'PG-13' ,'title_year':2019, 
             'budget':365000000, 'imdb_score': 8.4 , 'country': 'USA'}

bad_boys = {'director_name': 'Adil El Arbi' ,
             'duration':124 , 'actor_2_name':'Martin Lawrence' ,
                        'actor_1_name': 'Will Smith' ,
             'actor_3_name':"Vanessa Hudgens", 'gross':426500000  ,'movie_title': 'Bad Boys For Life',
             'facenumber_in_poster':2.0 , 'movie_imdb_link':'https://www.imdb.com/title/tt1502397/' ,
             'content_rating':'R' ,'title_year':2020, 
             'budget':90000000, 'imdb_score': 6.5 , 'country': 'USA'}

shang_chi =  {'director_name': 'Destin Daniel Cretton' ,
             'duration':124 , 'actor_2_name':'Awkwafina' ,
                        'actor_1_name': 'Simu Liu' ,
             'actor_3_name':"Tony Chiu-Wai Leung", 'gross':436500000  ,'movie_title': 'Shang-Chi and the Legend of the Ten Rings',
             'facenumber_in_poster':6.0 , 'movie_imdb_link':'https://www.imdb.com/title/tt9376612/' ,
             'content_rating':'PG-13' ,'title_year':2021, 
             'budget':175000000, 'imdb_score': 7.5 , 'country': 'USA'}


imdb_data_copy =imdb_data_copy.append(starwars_film, ignore_index=True)

imdb_data_copy =imdb_data_copy.append(dory_film,ignore_index=True)

imdb_data_copy =imdb_data_copy.append(second_starwars_film ,ignore_index=True)
imdb_data_copy =imdb_data_copy.append(black_panther,ignore_index=True)
imdb_data_copy =imdb_data_copy.append(end_game,ignore_index=True)
imdb_data_copy =imdb_data_copy.append(bad_boys,ignore_index=True)
imdb_data_copy =imdb_data_copy.append(shang_chi,ignore_index=True)

# %%
imdb_data_copy=imdb_data_copy[imdb_data_copy.index.notnull()].reset_index()
imdb_faces=imdb_data_copy[['title_year', 'facenumber_in_poster', 'movie_title' ]]

# %%
#I located the movies that weren't merging so I can rename them so they can be analyzed.

imdb_faces.at[237,'movie_title'] = 'Star Wars Ep. I: The Phantom Menace'
imdb_faces.at[14,'movie_title'] = 'Pirates of the Caribbean: Dead Man’s Chest'
imdb_faces.at[233,'movie_title'] = 'Star Wars Ep. III: Revenge of the Sith'
imdb_faces.at[200,'movie_title'] = 'Harry Potter and the Sorcerer’s Stone'

# %%
imdb_faces.dropna()
# Out:
#       title_year  facenumber_in_poster  \
# 0         2009.0                   0.0
# 1         2007.0                   0.0
# 2         2015.0                   1.0
# 3         2012.0                   0.0
# 5         2012.0                   1.0
# ...          ...                   ...
# 5000      2017.0                   7.0
# 5001      2018.0                  10.0
# 5002      2019.0                  11.0
# 5003      2020.0                   2.0
# 5004      2021.0                   6.0
#
#                                     movie_title
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 5                                  John Carter
# ...                                         ...
# 5000         Star Wars Ep. VIII: The Last Jedi
# 5001                              Black Panther
# 5002                          Avengers: Endgame
# ...

# %%
file_path_top = Path("Data/HighestGrossers.csv")
highest_grossers = pd.read_csv(file_path_top, index_col="YEAR")
highest_grossers.head()
# Out:
#                                     MOVIE      GENRE MPAA RATING  \
# YEAR
# 1995                       Batman Forever      Drama       PG-13
# 1996                     Independence Day  Adventure       PG-13
# 1997                         Men in Black  Adventure       PG-13
# 1998                              Titanic  Adventure       PG-13
# 1999  Star Wars Ep. I: The Phantom Menace  Adventure          PG
#
#              DISTRIBUTOR TOTAL FOR YEAR TOTAL IN 2019 DOLLARS TICKETS SOLD
# YEAR
# 1995        Warner Bros.   $184,031,112          $387,522,978  4,23,06,002
# 1996    20th Century Fox   $306,169,255          $634,504,608  6,92,69,062
# 1997       Sony Pictures   $250,650,052          $500,207,943  5,46,07,854
# 1998  Paramount Pictures   $443,319,081          $865,842,808  9,45,24,324
# 1999    20th Century Fox   $430,443,350          $776,153,749  8,47,32,942

# %%
imdb_faces['MOVIE'] = imdb_faces["movie_title"].str.rstrip()

movie_data_faces=pd.merge(
imdb_faces,
highest_grossers,
on='MOVIE'
)

# %%
movie_data_faces
# Out:
#     title_year  facenumber_in_poster  \
# 0       2007.0                   0.0
# 1       2007.0                   0.0
# 2       2013.0                   1.0
# 3       2012.0                   3.0
# 4       1997.0                   0.0
# 5       2013.0                   3.0
# 6       2009.0                   0.0
# 7       2010.0                   3.0
# 8       2008.0                   0.0
# 9       2014.0                   3.0
# 10      2002.0                   0.0
# 11      2011.0                   1.0
# 12      2001.0                   4.0
# 13      2000.0                   0.0
# 14      2005.0                   4.0
# 15      1999.0                   1.0
# 16      1995.0                   4.0
# 17      2003.0                   0.0
# 18      1997.0                   0.0
# 19      1996.0                   0.0
# 20      2004.0                   1.0
# 21      2015.0                   4.0
# 22      2016.0                   0.0
# 23      2017.0                   7.0
# ...

# %%
movie_data_faces = movie_data_faces.drop_duplicates()

# %%
movie_data_faces.at[4,'title_year']= 1998
movie_data_faces.at[2,'title_year']= 2006

# %%
movie_data_faces['title_year'] = movie_data_faces['title_year'].astype(int)

# %%
#highest grossing flim per year

movie_data_faces = movie_data_faces.drop(columns = 'movie_title')
movie_data_faces = movie_data_faces.set_index('title_year')
movie_data_faces = movie_data_faces.sort_index()

# %%
# fixing some of the data

#replaces specific values that I wanted to check 
movie_data_faces.at[1998,'facenumber_in_poster']= 2.0
movie_data_faces.at[1997,'facenumber_in_poster']= 2.0
movie_data_faces.at[2000,'facenumber_in_poster']= 1.0
movie_data_faces.at[2012,'facenumber_in_poster']= 6.0
movie_data_faces.at[2013,'facenumber_in_poster']= 5.0
movie_data_faces.at[1999,'facenumber_in_poster']= 4.0
movie_data_faces.at[2001,'facenumber_in_poster']= 5.0
movie_data_faces.at[2006,'facenumber_in_poster']= 3.0

# %% [markdown]
# The Highest Grossers Tables lists the top grossing movie for each year based on the tickets sold for each movie during the course of that respective year and also its corresponding year 2019 valuation(adjusted for inflation), Only NOrth AMerica

# %%
movie_data_faces
# Out:
#             facenumber_in_poster  \
# title_year
# 1995                         4.0
# 1996                         0.0
# 1997                         2.0
# 1998                         2.0
# 1999                         4.0
# 2000                         1.0
# 2001                         5.0
# 2002                         0.0
# 2003                         0.0
# 2004                         1.0
# 2005                         4.0
# 2006                         3.0
# 2007                         0.0
# 2008                         0.0
# 2009                         0.0
# 2010                         3.0
# 2011                         1.0
# 2012                         6.0
# 2013                         5.0
# 2014                         3.0
# 2015                         4.0
# 2016                         0.0
# 2017                         7.0
# 2018                        10.0
# 2019                        11.0
# 2020                         2.0
# 2021                         6.0
#
# ...

# %%
#Fix Tickets sold
movie_data_faces['TICKETS SOLD'] = movie_data_faces['TICKETS SOLD'].str.replace(',','')


#Fix Total Box Office Column
movie_data_faces['TOTAL FOR YEAR'] = movie_data_faces['TOTAL FOR YEAR'].str.replace(',','')
movie_data_faces['TOTAL FOR YEAR'] = movie_data_faces['TOTAL FOR YEAR'].str.replace('$','')
#Fix Inflation adjusted Column
movie_data_faces['TOTAL IN 2019 DOLLARS'] = movie_data_faces['TOTAL IN 2019 DOLLARS'].str.replace(',','')
movie_data_faces['TOTAL IN 2019 DOLLARS'] = movie_data_faces['TOTAL IN 2019 DOLLARS'].str.replace('$','')

# %%
movie_data_faces #ready for analysis.
#could use gross column in movie_metaverse as well
# Out:
#             facenumber_in_poster  \
# title_year
# 1995                         4.0
# 1996                         0.0
# 1997                         2.0
# 1998                         2.0
# 1999                         4.0
# 2000                         1.0
# 2001                         5.0
# 2002                         0.0
# 2003                         0.0
# 2004                         1.0
# 2005                         4.0
# 2006                         3.0
# 2007                         0.0
# 2008                         0.0
# 2009                         0.0
# 2010                         3.0
# 2011                         1.0
# 2012                         6.0
# 2013                         5.0
# 2014                         3.0
# 2015                         4.0
# 2016                         0.0
# 2017                         7.0
# 2018                        10.0
# 2019                        11.0
# 2020                         2.0
# 2021                         6.0
#
# ...

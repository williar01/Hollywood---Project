# %%
# imports
import scipy
#import xarray

import panel as pn
#pn.extension('plotly')
import pandas as pd
import hvplot.pandas
import matplotlib.pyplot as plt
import numpy as np
import os
from pathlib import Path
from dotenv import load_dotenv
import warnings
warnings.filterwarnings('ignore')
import plotly.express as px
from pandas_profiling import ProfileReport
import sweetviz
# %matplotlib inline

# %%
# Read the movies_dataset into a Pandas DataFrame
file_path = Path("./Data")
imdb_data = pd.read_csv(f"{file_path}/movie_metadata.csv", index_col='title_year',parse_dates=True,encoding= 'unicode_escape')
annual_ticket_sales = pd.read_csv(f"{file_path}/AnnualTicketSales.csv",parse_dates=True)
highest_grossers = pd.read_csv(f"{file_path}/HighestGrossers.csv",parse_dates=True)
popular_creative_types = pd.read_csv(f"{file_path}/PopularCreativeTypes.csv",parse_dates=True)
top_distributors = pd.read_csv(f"{file_path}/TopDistributors.csv",parse_dates=True)
top_genres = pd.read_csv(f"{file_path}/TopGenres.csv",parse_dates=True)
top_grossing_ratings = pd.read_csv(f"{file_path}/TopGrossingRatings.csv",parse_dates=True)
top_grossing_sources = pd.read_csv(f"{file_path}/TopGrossingSources.csv",parse_dates=True)
top_production_methods = pd.read_csv(f"{file_path}/TopProductionMethods.csv",parse_dates=True)
wide_release_count = pd.read_csv(f"{file_path}/WideReleasesCount.csv",parse_dates=True)
imdb_data.head()
# Out:
#             color      director_name  num_critic_for_reviews  duration  \
# title_year
# 2009-01-01  Color      James Cameron                   723.0     178.0
# 2007-01-01  Color     Gore Verbinski                   302.0     169.0
# 2015-01-01  Color         Sam Mendes                   602.0     148.0
# 2012-01-01  Color  Christopher Nolan                   813.0     164.0
# NaT           NaN        Doug Walker                     NaN       NaN
#
#             director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# title_year
# 2009-01-01                      0.0                   855.0  Joel David Moore
# 2007-01-01                    563.0                  1000.0     Orlando Bloom
# 2015-01-01                      0.0                   161.0      Rory Kinnear
# 2012-01-01                  22000.0                 23000.0    Christian Bale
# NaT                           131.0                     NaN        Rob Walker
#
#             actor_1_facebook_likes        gross  \
# title_year
# 2009-01-01                  1000.0  760505847.0
# 2007-01-01                 40000.0  309404152.0
# 2015-01-01                 11000.0  200074175.0
# 2012-01-01                 27000.0  448130642.0
# NaT                          131.0          NaN
#
#                                      genres  ...  \
# title_year                                   ...
# 2009-01-01  Action|Adventure|Fantasy|Sci-Fi  ...
# 2007-01-01         Action|Adventure|Fantasy  ...
# 2015-01-01        Action|Adventure|Thriller  ...
# 2012-01-01                  Action|Thriller  ...
# NaT                             Documentary  ...
#
#                                               movie_imdb_link  \
# title_year
# 2009-01-01  http://www.imdb.com/title/tt0499549/?ref_=fn_t...
# 2007-01-01  http://www.imdb.com/title/tt0449088/?ref_=fn_t...
# 2015-01-01  http://www.imdb.com/title/tt2379713/?ref_=fn_t...
# 2012-01-01  http://www.imdb.com/title/tt1345836/?ref_=fn_t...
# NaT         http://www.imdb.com/title/tt5289954/?ref_=fn_t...
#
#            num_user_for_reviews  language  country content_rating  \
# title_year
# 2009-01-01               3054.0   English      USA          PG-13
# 2007-01-01               1238.0   English      USA          PG-13
# 2015-01-01                994.0   English       UK          PG-13
# 2012-01-01               2701.0   English      USA          PG-13
# NaT                         NaN       NaN      NaN            NaN
#
#                  budget actor_2_facebook_likes imdb_score  aspect_ratio  \
# title_year
# 2009-01-01  237000000.0                  936.0        7.9          1.78
# 2007-01-01  300000000.0                 5000.0        7.1          2.35
# 2015-01-01  245000000.0                  393.0        6.8          2.35
# 2012-01-01  250000000.0                23000.0        8.5          2.35
# NaT                 NaN                   12.0        7.1           NaN
#
#            movie_facebook_likes
# title_year
# 2009-01-01                33000
# 2007-01-01                    0
# 2015-01-01                85000
# 2012-01-01               164000
# NaT                           0
#
# [5 rows x 27 columns]

# %%
highest_grossers_copy['TOTAL FOR YEAR'] = highest_grossers_copy['TOTAL FOR YEAR'].str.replace(',','')
highest_grossers_copy['TOTAL FOR YEAR'] = highest_grossers_copy['TOTAL FOR YEAR'].str.replace('$','')
highest_grossers_copy['TOTAL FOR YEAR'] = highest_grossers_copy['TOTAL FOR YEAR'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8136/2199018299.py in <module>
# ----> 1 highest_grossers_copy['TOTAL FOR YEAR'] = highest_grossers_copy['TOTAL FOR YEAR'].str.replace(',','')
#       2 highest_grossers_copy['TOTAL FOR YEAR'] = highest_grossers_copy['TOTAL FOR YEAR'].str.replace('$','')
#       3 highest_grossers_copy['TOTAL FOR YEAR'] = highest_grossers_copy['TOTAL FOR YEAR'].astype(int)
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
#     180             return self._accessor
# --> 181         accessor_obj = self._accessor(obj)
#     182         # Replace the property with the accessor object. Inspired by:
#     183         # https://www.pydanny.com/cached-property.html
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\strings\accessor.py in __init__(self, data)
#     166         from pandas.core.arrays.string_ import StringDtype
#     167
# --> 168         self._inferred_dtype = self._validate(data)
#     169         self._is_categorical = is_categorical_dtype(data.dtype)
#     170         self._is_string = isinstance(data.dtype, StringDtype)
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\core\strings\accessor.py in _validate(data)
#     223
#     224         if inferred_dtype not in allowed_types:
# --> 225             raise AttributeError("Can only use .str accessor with string values!")
#     226         return inferred_dtype
#     227
#
# AttributeError: Can only use .str accessor with string values!

# %%
highest_grossers_copy
# Out:
#     YEAR                                          MOVIE      GENRE  \
# 0   1995                                 Batman Forever      Drama
# 1   1996                               Independence Day  Adventure
# 2   1997                                   Men in Black  Adventure
# 3   1998                                        Titanic  Adventure
# 4   1999            Star Wars Ep. I: The Phantom Menace  Adventure
# 5   2000                 How the Grinch Stole Christmas  Adventure
# 6   2001          Harry Potter and the Sorcerer’s Stone  Adventure
# 7   2002                                     Spider-Man  Adventure
# 8   2003                                   Finding Nemo  Adventure
# 9   2004                                        Shrek 2  Adventure
# 10  2005         Star Wars Ep. III: Revenge of the Sith     Action
# 11  2006     Pirates of the Caribbean: Dead Man’s Chest     Action
# 12  2007                                   Spider-Man 3  Adventure
# 13  2008                                The Dark Knight  Adventure
# 14  2009            Transformers: Revenge of the Fallen     Action
# 15  2010                                    Toy Story 3     Action
# 16  2011  Harry Potter and the Deathly Hallows: Part II     Action
# 17  2012                                   The Avengers  Adventure
# 18  2013                                     Iron Man 3  Adventure
# 19  2014                        Guardians of the Galaxy  Adventure
# 20  2015           Star Wars Ep. VII: The Force Awakens     Action
# 21  2016                                   Finding Dory     Action
# 22  2017              Star Wars Ep. VIII: The Last Jedi     Action
# 23  2018                                  Black Panther     Action
# 24  2019                              Avengers: Endgame        NaN
# 25  2020                              Bad Boys For Life        NaN
# 26  2021      Shang-Chi and the Legend of the Ten Rings        NaN
#
#    MPAA RATING         DISTRIBUTOR  TOTAL FOR YEAR TOTAL IN 2019 DOLLARS  \
# 0        PG-13        Warner Bros.       184031112          $387,522,978
# 1        PG-13    20th Century Fox       306169255          $634,504,608
# 2        PG-13       Sony Pictures       250650052          $500,207,943
# 3        PG-13  Paramount Pictures       443319081          $865,842,808
# 4           PG    20th Century Fox       430443350          $776,153,749
# 5           PG           Universal       253367455          $430,583,644
# 6           PG        Warner Bros.       300404434          $486,166,890
# 7        PG-13       Sony Pictures       403706375          $636,480,273
# 8            G         Walt Disney       339714367          $516,050,346
# 9           PG      Dreamworks SKG       441226247          $650,826,473
# 10       PG-13    20th Century Fox       380270577          $543,413,171
# 11       PG-13         Walt Disney       423315812          $591,995,851
# 12       PG-13       Sony Pictures       336530303          $448,054,878
# 13       PG-13        Warner Bros.       531001578          $677,433,772
# 14       PG-13  Paramount Pictures       402111870          $491,112,631
# 15           G         Walt Disney       415004880          $481,805,411
# 16       PG-13        Warner Bros.       381011219          $440,108,798
# 17       PG-13         Walt Disney       623357910          $717,331,462
# 18       PG-13         Walt Disney       408992272          $460,808,016
# 19       PG-13         Walt Disney       333055258          $373,413,235
# 20       PG-13         Walt Disney       742208942          $806,480,887
# 21          PG         Walt Disney       486295561          $514,967,322
# 22       PG-13         Walt Disney       517218368          $528,173,936
# 23       PG-13         Walt Disney       700059566          $703,901,821
# 24       PG-13         Walt Disney       858373000          $858,373,002
# 25           R       Sony Pictures       204417855          $204,417,848
# 26       PG-13         Walt Disney       224226704          $224,226,704
#
#    TICKETS SOLD
# 0   4,23,06,002
# 1   6,92,69,062
# 2   5,46,07,854
# 3   9,45,24,324
# 4   8,47,32,942
# 5   4,70,06,948
# 6   5,30,74,988
# 7   6,94,84,746
# 8   5,63,37,374
# 9   7,10,50,925
# 10  5,93,24,582
# 11  6,46,28,368
# 12  4,89,14,288
# 13  7,39,55,652
# 14  5,36,14,916
# 15  5,25,98,844
# 16  4,80,46,812
# 17  7,83,11,295
# 18  5,03,06,552
# 19  4,07,65,637
# 20  8,80,43,765
# 21  5,62,19,140
# 22  5,76,60,910
# 23  7,68,45,177
# 24  9,37,08,843
# 25  2,23,16,359
# 26  2,44,78,897

# %%
highest_grossers_copy.plot.bar(figsize=(15,10), x='MOVIE', y='TOTAL FOR YEAR', title='Highest Grossers')
# Out:
# <AxesSubplot:title={'center':'Highest Grossers'}, xlabel='MOVIE'>

# %%
imdb_data_copy=imdb_data.groupby('actor_1_name')['gross']. sum()

# %%
imdb_data_copy
# Out:
# actor_1_name
# 50 Cent                 30981850.0
# A.J. Buckley           123070338.0
# Aaliyah                 30307804.0
# Aasif Mandvi            13214030.0
# Abbie Cornish           75103149.0
#                           ...
# Zooey Deschanel        181844082.0
# Zuhair Haddad                  0.0
# lafur Darri lafsson            0.0
# scar Jaenada            54257433.0
# lex Angulo                    0.0
# Name: gross, Length: 2097, dtype: float64

# %%
#imdb_data_copy.reset_index(inplace=True)

# %%
imdb_data['actor_1_name'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')
# Out:
# title_year
# 2009-01-01        CCH Pounder
# 2007-01-01        Johnny Depp
# 2015-01-01    Christoph Waltz
# 2012-01-01          Tom Hardy
# NaT               Doug Walker
#                    ...
# 2013-01-01        Eric Mabius
# NaT               Natalie Zea
# 2013-01-01        Eva Boehnke
# 2012-01-01          Alan Ruck
# 2004-01-01        John August
# Name: actor_1_name, Length: 5043, dtype: object

# %%
imdb_data['director_name']
# Out:
# title_year
# 2009-01-01        James Cameron
# 2007-01-01       Gore Verbinski
# 2015-01-01           Sam Mendes
# 2012-01-01    Christopher Nolan
# NaT                 Doug Walker
#                     ...
# 2013-01-01          Scott Smith
# NaT                         NaN
# 2013-01-01     Benjamin Roberds
# 2012-01-01          Daniel Hsia
# 2004-01-01             Jon Gunn
# Name: director_name, Length: 5043, dtype: object

# %%
imdb_data_copy=imdb_data.groupby('actor_1_name')['gross']. sum()
